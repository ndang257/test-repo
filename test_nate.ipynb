# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import mysql.connector

# %%
db_connection = mysql.connector.connect(host='localhost', database='obeta_db', user='root', password='Mysql123', port=3306)
db_cursor = db_connection.cursor()
db_cursor.execute("SELECT * FROM pick_data")

table_rows = db_cursor.fetchall()

pick_data = pd.DataFrame(table_rows)

# %%
sns.histplot(pick_St, bins=30, kde=True)
plt.title('Distribution of Pick Volume for Quantity Unit "St"')
plt.xlabel('Pick Volume')
plt.ylabel('Frequency')
plt.show()

# %%
print(pick_St.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28621621 entries, 0 to 28621620
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       int64
# dtypes: int64(1)
# memory usage: 218.4 MB
# None
